# %%
# %%

import pandas as pd
from collections import Counter

# Load spam.csv
file_path = "spam.csv"  # Replace with the actual file path
data = pd.read_csv(file_path, encoding='latin-1')

# Clean up the dataset (adjust columns as per the dataset structure)
data = data.rename(columns={"v1": "label", "v2": "message"})
data = data[["label", "message"]]

# Compute statistics
num_messages = len(data)
num_spam = len(data[data["label"] == "spam"])
num_ham = len(data[data["label"] == "ham"])

# Word count statistics
word_counts = data["message"].str.split().map(len)
total_words = word_counts.sum()
avg_words = word_counts.mean()

# Most frequent words
all_words = " ".join(data["message"]).split()
word_freq = Counter(all_words)
most_common_words = word_freq.most_common(5)

# Rare words (appear only once)
rare_words = [word for word, count in word_freq.items() if count == 1]
num_rare_words = len(rare_words)

# Output
print(f"Total messages: {num_messages}")
print(f"Spam messages: {num_spam}")
print(f"Non-spam (ham) messages: {num_ham}")
print(f"Total words: {total_words}")
print(f"Average words per message: {avg_words:.2f}")
print(f"5 most frequent words: {most_common_words}")
print(f"Number of rare words: {num_rare_words}")
# Out:
# Total messages: 5572
# Spam messages: 747
# Non-spam (ham) messages: 4825
# Total words: 86335
# Average words per message: 15.49
# 5 most frequent words: [('to', 2134), ('you', 1622), ('I', 1466), ('a', 1327), ('the', 1197)]
# Number of rare words: 9268

# %%
# %%

import matplotlib.pyplot as plt
import seaborn as sns

# Plot Spam vs. Ham count
spam_ham_counts = data["label"].value_counts()

plt.figure(figsize=(8, 6))
sns.barplot(x=spam_ham_counts.index, y=spam_ham_counts.values, palette="viridis")
plt.title("Spam vs. Ham Message Count", fontsize=16)
plt.xlabel("Message Type", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.show()

# Plot Word Count Distribution
plt.figure(figsize=(10, 6))
sns.histplot(word_counts, kde=True, bins=30, color="blue")
plt.title("Word Count Distribution in Messages", fontsize=16)
plt.xlabel("Number of Words", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.show()
# Out:
# <ipython-input-6-70bece70f4d5>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=spam_ham_counts.index, y=spam_ham_counts.values, palette="viridis")

# %%
# %% 

import nltk
import spacy

# Download NLTK tokenizer resources
nltk.download('punkt')

# NLTK Tokenization
nltk_tokens = data["message"].apply(nltk.word_tokenize)

# spaCy Tokenization
nlp = spacy.load("en_core_web_sm")
spacy_tokens = data["message"].apply(lambda x: [token.text for token in nlp(x)])

# Compare results
print(f"NLTK Tokenization example: {nltk_tokens.iloc[0]}")
print(f"spaCy Tokenization example: {spacy_tokens.iloc[0]}")
# Out:
# [nltk_data] Downloading package punkt to /Users/matanoz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# NLTK Tokenization example: ['Go', 'until', 'jurong', 'point', ',', 'crazy', '..', 'Available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'Cine', 'there', 'got', 'amore', 'wat', '...']
# spaCy Tokenization example: ['Go', 'until', 'jurong', 'point', ',', 'crazy', '..', 'Available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'Cine', 'there', 'got', 'amore', 'wat', '...']

# %%
# %% 

import nltk
import spacy

# Download NLTK tokenizer resources
nltk.download('punkt')

# NLTK Tokenization
nltk_tokens = data["message"].apply(nltk.word_tokenize)

# spaCy Tokenization
nlp = spacy.load("en_core_web_sm")
spacy_tokens = data["message"].apply(lambda x: [token.text for token in nlp(x)])

# Compare results
print(f"NLTK Tokenization example: {nltk_tokens.iloc[10]}")
print(f"spaCy Tokenization example: {spacy_tokens.iloc[10]}")
# Out:
# [nltk_data] Downloading package punkt to /Users/matanoz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# NLTK Tokenization example: ['I', "'m", 'gon', 'na', 'be', 'home', 'soon', 'and', 'i', 'do', "n't", 'want', 'to', 'talk', 'about', 'this', 'stuff', 'anymore', 'tonight', ',', 'k', '?', 'I', "'ve", 'cried', 'enough', 'today', '.']
# spaCy Tokenization example: ['I', "'m", 'gon', 'na', 'be', 'home', 'soon', 'and', 'i', 'do', "n't", 'want', 'to', 'talk', 'about', 'this', 'stuff', 'anymore', 'tonight', ',', 'k', '?', 'I', "'ve", 'cried', 'enough', 'today', '.']

# %%
# %% 

import nltk
import spacy

# Download NLTK tokenizer resources
nltk.download('punkt')

# NLTK Tokenization
nltk_tokens = data["message"].apply(nltk.word_tokenize)

# spaCy Tokenization
nlp = spacy.load("en_core_web_sm")
spacy_tokens = data["message"].apply(lambda x: [token.text for token in nlp(x)])

# Compare results
print(f"NLTK Tokenization example: {nltk_tokens.iloc[:10]}")
print(f"spaCy Tokenization example: {spacy_tokens.iloc[:10]}")
# Out:
# [nltk_data] Downloading package punkt to /Users/matanoz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# NLTK Tokenization example: 0    [Go, until, jurong, point, ,, crazy, .., Avail...
# 1             [Ok, lar, ..., Joking, wif, u, oni, ...]
# 2    [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 3    [U, dun, say, so, early, hor, ..., U, c, alrea...
# 4    [Nah, I, do, n't, think, he, goes, to, usf, ,,...
# 5    [FreeMsg, Hey, there, darling, it, 's, been, 3...
# 6    [Even, my, brother, is, not, like, to, speak, ...
# 7    [As, per, your, request, 'Melle, Melle, (, Oru...
# 8    [WINNER, !, !, As, a, valued, network, custome...
# 9    [Had, your, mobile, 11, months, or, more, ?, U...
# Name: message, dtype: object
# spaCy Tokenization example: 0    [Go, until, jurong, point, ,, crazy, .., Avail...
# 1             [Ok, lar, ..., Joking, wif, u, oni, ...]
# 2    [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 3    [U, dun, say, so, early, hor, ..., U, c, alrea...
# 4    [Nah, I, do, n't, think, he, goes, to, usf, ,,...
# 5    [FreeMsg, Hey, there, darling, it, 's, been, 3...
# 6    [Even, my, brother, is, not, like, to, speak, ...
# 7    [As, per, your, request, ', Melle, Melle, (, O...
# 8    [WINNER, !, !, As, a, valued, network, custome...
# 9    [Had, your, mobile, 11, months, or, more, ?, U...
# Name: message, dtype: object

# %%
# %%

# Q6
from nltk.stem import WordNetLemmatizer
import nltk

# Download NLTK lemmatizer resources
nltk.download('wordnet')
nltk.download('omw-1.4')

# NLTK Lemmatization
lemmatizer = WordNetLemmatizer()
nltk_lemmatized = data["message"].apply(lambda x: [lemmatizer.lemmatize(word) for word in nltk.word_tokenize(x)])

# spaCy Lemmatization
spacy_lemmatized = data["message"].apply(lambda x: [token.lemma_ for token in nlp(x)])

# Display example results
print(f"NLTK Lemmatization example: {nltk_lemmatized.iloc[0]}")
print(f"spaCy Lemmatization example: {spacy_lemmatized.iloc[0]}")
# Out:
# [nltk_data] Downloading package wordnet to /Users/matanoz/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/matanoz/nltk_data...
# NLTK Lemmatization example: ['Go', 'until', 'jurong', 'point', ',', 'crazy', '..', 'Available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'Cine', 'there', 'got', 'amore', 'wat', '...']
# spaCy Lemmatization example: ['go', 'until', 'jurong', 'point', ',', 'crazy', '..', 'available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'Cine', 'there', 'get', 'amore', 'wat', '...']

# %%
# %%

#q7

from nltk.stem import PorterStemmer

# NLTK Stemming
stemmer = PorterStemmer()
nltk_stemmed = data["message"].apply(lambda x: [stemmer.stem(word) for word in nltk.word_tokenize(x)])

# Display NLTK Stemming example
print(f"NLTK Stemming example: {nltk_stemmed.iloc[0]}")
# Out:
# NLTK Stemming example: ['go', 'until', 'jurong', 'point', ',', 'crazi', '..', 'avail', 'onli', 'in', 'bugi', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'cine', 'there', 'got', 'amor', 'wat', '...']

# %%
# %%

#q7

from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer
from nltk.tokenize import word_tokenize
import nltk

# Download required NLTK resources
nltk.download('punkt')

# Initialize stemmers
porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer()
snowball_stemmer = SnowballStemmer("english")

# Apply all stemmers to the dataset
def apply_stemming_methods(text):
    tokens = word_tokenize(text)
    porter_stemmed = [porter_stemmer.stem(word) for word in tokens]
    lancaster_stemmed = [lancaster_stemmer.stem(word) for word in tokens]
    snowball_stemmed = [snowball_stemmer.stem(word) for word in tokens]
    return {
        "original": tokens,
        "porter": porter_stemmed,
        "lancaster": lancaster_stemmed,
        "snowball": snowball_stemmed,
    }

# Test stemming on the first message
example_message = data["message"].iloc[0]
stemmed_results = apply_stemming_methods(example_message)

# Display results
print("Original Tokens:", stemmed_results["original"])
print("Porter Stemmer:", stemmed_results["porter"])
print("Lancaster Stemmer:", stemmed_results["lancaster"])
print("Snowball Stemmer:", stemmed_results["snowball"])
# Out:
# Original Tokens: ['Go', 'until', 'jurong', 'point', ',', 'crazy', '..', 'Available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'Cine', 'there', 'got', 'amore', 'wat', '...']
# Porter Stemmer: ['go', 'until', 'jurong', 'point', ',', 'crazi', '..', 'avail', 'onli', 'in', 'bugi', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'cine', 'there', 'got', 'amor', 'wat', '...']
# Lancaster Stemmer: ['go', 'until', 'jurong', 'point', ',', 'crazy', '..', 'avail', 'on', 'in', 'bug', 'n', 'gre', 'world', 'la', 'e', 'buffet', '...', 'cin', 'ther', 'got', 'am', 'wat', '...']
# Snowball Stemmer: ['go', 'until', 'jurong', 'point', ',', 'crazi', '..', 'avail', 'onli', 'in', 'bugi', 'n', 'great', 'world', 'la', 'e', 'buffet', '...', 'cine', 'there', 'got', 'amor', 'wat', '...']
# [nltk_data] Downloading package punkt to /Users/matanoz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# %%

#q8
import nltk
import spacy
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from collections import Counter

# Download resources for NLTK
nltk.download('punkt')
nltk.download('wordnet')

# Initialize spaCy
spacy_nlp = spacy.load("en_core_web_sm")

# Initialize NLTK Lemmatizer
nltk_lemmatizer = WordNetLemmatizer()

# Function to tokenize messages
def tokenize_message(message, method="NLTK"):
    if method == "NLTK":
        return word_tokenize(message)
    elif method == "spaCy":
        return [token.text for token in spacy_nlp(message)]
    else:
        raise ValueError("Invalid method. Choose 'NLTK' or 'spaCy'.")

# Function to lemmatize tokens
def lemmatize_tokens(tokens, method="NLTK"):
    if method == "NLTK":
        return [nltk_lemmatizer.lemmatize(token) for token in tokens]
    elif method == "spaCy":
        return [token.lemma_ for token in spacy_nlp(" ".join(tokens))]
    else:
        raise ValueError("Invalid method. Choose 'NLTK' or 'spaCy'.")

# Combine tokens from all messages
def get_combined_tokens(data, method="NLTK"):
    all_tokens = []
    for message in data["message"]:
        tokens = tokenize_message(message, method=method)
        all_tokens.extend(tokens)
    return all_tokens

# Main logic to find the first removable message
def find_first_removable_message(data, method="NLTK"):
    combined_tokens = get_combined_tokens(data, method=method)
    combined_lemmas = lemmatize_tokens(combined_tokens, method=method)
    
    for index, row in data.iterrows():
        # Remove one message
        temp_data = data.drop(index)
        
        # Regenerate combined tokens and lemmas
        #temp_combined_tokens = get_combined_tokens(temp_data, method=method)
        temp_combined_lemmas = lemmatize_tokens(temp_combined_tokens, method=method)
        
        # Check if lemmas remain unchanged
        if Counter(temp_combined_lemmas) == Counter(combined_lemmas):
            print(index)
            return row["message"]  # Return the first removable message
    
    return None  # No message found

# Example usage
method = "NLTK"  # or "spaCy"
removable_message = find_first_removable_message(data, method=method)

if removable_message:
    print(f"The first removable message: {removable_message}")
else:
    print("No such message found.")
# Out:
# [nltk_data] Downloading package punkt to /Users/matanoz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/matanoz/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /Users/matanoz/Documents/לימודים תואר שני/סמסטר ג׳/NLP-lab/main.py:67
#      65 # Example usage
#      66 method = "NLTK"  # or "spaCy"
# ---> 67 removable_message = find_first_removable_message(data, method=method)
#      69 if removable_message:
#      70     print(f"The first removable message: {removable_message}")
#
# File /Users/matanoz/Documents/לימודים תואר שני/סמסטר ג׳/NLP-lab/main.py:56
#      52 temp_data = data.drop(index)
#      54 # Regenerate combined tokens and lemmas
#      55 #temp_combined_tokens = get_combined_tokens(temp_data, method=method)
# ---> 56 temp_combined_lemmas = lemmatize_tokens(temp_combined_tokens, method=method)
#      58 # Check if lemmas remain unchanged
#      59 if Counter(temp_combined_lemmas) == Counter(combined_lemmas):
#
# NameError: name 'temp_combined_tokens' is not defined

# %%
# %%

#q8

import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import spacy

# Download required NLTK resources
nltk.download('punkt')
nltk.download('wordnet')

# Initialize tools
nltk_lemmatizer = WordNetLemmatizer()
spacy_nlp = spacy.load("en_core_web_sm")

# Function to tokenize messages
def tokenize_messages(messages, method="NLTK"):
   if method == "NLTK":
       return messages.apply(word_tokenize)
   elif method == "spaCy":
       return messages.apply(lambda x: [token.text for token in spacy_nlp(x)])
   else:
       raise ValueError("Invalid method. Choose 'NLTK' or 'spaCy'.")

# Function to lemmatize tokens
def lemmatize_tokens(token_vectors, method="NLTK"):
   if method == "NLTK":
       return token_vectors.apply(lambda tokens: [nltk_lemmatizer.lemmatize(token) for token in tokens])
   elif method == "spaCy":
       return token_vectors.apply(lambda tokens: [spacy_nlp(token)[0].lemma_ for token in tokens])
   else:
       raise ValueError("Invalid method. Choose 'NLTK' or 'spaCy'.")

# Generate combined vector of all tokens
def generate_combined_vector(messages, method="NLTK"):
   token_vectors = tokenize_messages(messages, method)
   return [token for message_tokens in token_vectors for token in message_tokens]

# Find the first message that does not change the lemmatized vector
def find_first_removal_message(messages, method="NLTK"):
   combined_vector = generate_combined_vector(messages, method)
   combined_lemmatized = set(lemmatize_tokens(pd.Series([combined_vector]), method)[0])
   
   for index, message in messages.items():
       temp_messages = messages.drop(index)
       temp_vector = generate_combined_vector(temp_messages, method)
       temp_lemmatized = set(lemmatize_tokens(pd.Series([temp_vector]), method)[0])
       
       if temp_lemmatized == combined_lemmatized:
           return message
   return None

# Example usage
messages = data["message"]  # Replace with your dataset column
method = "NLTK"  # Change to "spaCy" if preferred

result_message = find_first_removal_message(messages, method)
if result_message:
   print("Message found:", result_message)
else:
   print("No such message found.")
# Out:
# [nltk_data] Downloading package punkt to /Users/matanoz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/matanoz/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Message found: Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's

# %%
# %%

import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import spacy

# Download required NLTK resources
nltk.download('punkt')
nltk.download('wordnet')

# Initialize tools
nltk_lemmatizer = WordNetLemmatizer()
spacy_nlp = spacy.load("en_core_web_sm")

# Function to tokenize messages
def tokenize_messages(messages, method="NLTK"):
    if method == "NLTK":
        return messages.apply(word_tokenize)
    elif method == "spaCy":
        return messages.apply(lambda x: [token.text for token in spacy_nlp(x)])
    else:
        raise ValueError("Invalid method. Choose 'NLTK' or 'spaCy'.")

# Function to lemmatize tokens
def lemmatize_tokens(token_vectors, method="NLTK"):
    if method == "NLTK":
        return token_vectors.apply(lambda tokens: [nltk_lemmatizer.lemmatize(token) for token in tokens])
    elif method == "spaCy":
        return token_vectors.apply(lambda tokens: [spacy_nlp(token)[0].lemma_ for token in tokens])
    else:
        raise ValueError("Invalid method. Choose 'NLTK' or 'spaCy'.")

# Generate combined vector of all tokens
def generate_combined_vector(messages, method="NLTK"):
    token_vectors = tokenize_messages(messages, method)
    return [token for message_tokens in token_vectors for token in message_tokens]

# Find the first message that does not change the lemmatized vector
def find_first_removal_message(messages, method="NLTK"):
    combined_vector = generate_combined_vector(messages, method)
    combined_lemmatized = set(lemmatize_tokens(pd.Series([combined_vector]), method)[0])
    
    for index, message in messages.items():
        temp_messages = messages.drop(index)
        temp_vector = generate_combined_vector(temp_messages, method)
        temp_lemmatized = set(lemmatize_tokens(pd.Series([temp_vector]), method)[0])
        
        if temp_lemmatized == combined_lemmatized:
            # Proof: Return relevant details
            return {
                "index": index,
                "message": message,
                "original_lemmatized": combined_lemmatized,
                "modified_lemmatized": temp_lemmatized,
                "proof": "The lemmatized vectors are identical, so removing this message does not affect lemmatized tokens."
            }
    return None

# Example usage
messages = data["message"]  # Replace with your dataset column
method = "NLTK"  # Change to "spaCy" if preferred

result = find_first_removal_message(messages, method)
if result:
    print(f"Message index: {result['index']}")
    print(f"Message: {result['message']}")
    print(f"Original lemmatized vector: {result['original_lemmatized']}")
    print(f"Modified lemmatized vector: {result['modified_lemmatized']}")
    print(f"Proof: {result['proof']}")
else:
    print("No such message found.")
# Out:
# [nltk_data] Downloading package punkt to /Users/matanoz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/matanoz/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Message index: 2
# Message: Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# Original lemmatized vector: {'brum', 'www.txt-2-shop.com', 'yoville', 'fowler', 'swann', 'mt', 'gossip', 'HAV', '-P', 'get4an18th', 'Don\x89Û÷t', 'person.Meet', 'grumble', 'abt', 'dealing', 'NO-165', 'individual', 'last', 'w1t1jy', 'Twittering', 'DE', 'LtdHelpDesk', 'mumHas', '25', 'eå£nd', 'njan', 'channel', 'operator', 'Subs', 'prolly', 'them', 'survey', '24th', 'northampton', 'KNOWS', 'More', 'green', 'mode', 'offline', 'Sagamu', 'Hello\\', 'message', 'canlove', 'renewing', 'drvgsTo', 'spk', 'win150ppmx3age16', 'fifteen', 'sd', 'support', 'rumbling', 'slowly', 'Smith', 'SOON', 'videosounds+2', 'great.bye', 'blimey', 'Oops', '87070', 'Lul', 'T-Mobile', 'Each', 'Iyo', 'personal', '151', 'derek', 'priest', 'person', 'chennai', 'kz', 'Guess', '82242', '2day.love', 'odi', 'wildlife', 'PlanetTalkInstant.com', 'INVITED', 'smeone', 'hunny', '08714712379', 'shldxxxx', 'ego', 'flow', 'iZ', 'jiu', 'W14RG', 'possessiveness', 'math', 'yeovil', 'CAREFUL', 'Shivratri', 'MISSED', 'physic', 'gym', 'w8in', 'Yun', 'dose', 'TOTALLY', 'LUV', 'hamper', 'strt', 'Videos', 'Saeed', 'Sometimes', 'failing', 'Jackpot', '09061702893', 'pickle', 'Chat80155', 'itcould', 'E.G.23F', '4.49/month', 'FREEPHONE', 'Pray', 'bowl', 'Read', 'snowman', 'Urgh', 'Horrible', 'urgently', '118p/msg', 'Hype', 'chance', 'telly', 'tookplace', 'Become', 'become', 'badly', 'PIN', 'Queries', 'Wins', 'dined', 'gave', 'GOODFRIEND', 'missed', 'Ptbo', 'REALLY', 'Yep', 'URL', 'Australia', 'a', 'Yalru', '09064017295', 'muchand', 'base', 'motherfucker', 'lookin', 'provided', 'ansr', 'nail', 'java', 'fgkslpo', 'fishhead', 'orc', 'matter', 'shortly', '4thNOV.BEHIND', 'pg', 'unsubscribe', 'yourinclusive', 'volcano', 'NUMBER-SO', 'flea', 'GOODTIME', 'prescripiton', '2go.did', 'YES-165', '4-7/12', 'bos', '4.50', 'scratch', 'kiosk', 'Join', '09058094597', '7ish', 'unfortuntly', '7', 'WORDS', 'selflessness', '3qxj9', 'LOOKIN', 'account', 'Rajitha', 'MARSMS', 'sparkling', 'Common', 'temper', 'wkg', 'Everytime', 'Dorothy', 'Emily', 'clue', 'cheek', 'qatar', 'atlast', 'profit', 'frens', 'salmon', 'first', 'mornin', 'Nokia', 'gd', 'tear', 'lecture', 'Minimum', 'LIKELY', 'james', 'Abiola', 'pocked', 'Tomarrow', 'performed', 'oga', 'magicalsongs.blogspot.com', 'refreshed', 'alert', 'Nite', '021', 'MARCH', 'FML', 'semester', 'that\x89Û÷s', 'dippeditinaDEW', 'flower', 'billion', '3AJ', 'Yesterday', 'AVA', 'ad', 'progress', 'purse', "'anything", 'me.Remove', 'Hugs', 'tonite.things', '24/7MP', 'EURO', 'Girl', 'renting', 'Then', 'wishin', 'å£350', 'section', 'INK', 'he', 'Gal', 'husband', 'b', 'sony', 'blame', 'Happy', 'Drop', 'bootydelious', 'ovarian', 'arises', '2.IM', 'urination', 'sacked', 'ax', 'hai', 'mutai', 'ppm', 'won', 'technical', 'gnun', '8+6+3=', 'earliest', 'QUITEAMUZING', 'paining', 'KEEP', 'macho', 'remember', 'wildest', 'bad-', 'GOWER', 'Nt', 'bw', '\\HI', 'gist', 'prior', 'creep', 'Rally', 'yi', 'ended', 'Melle', 'tie-pos', 'lodge', 'birth', 'seeker', 'Alaikkum.Pride', 'recovery', 'subsequent', 'Jamster', 'London', 'virgil', 'ou', 'Lands', 'contact', 'Next', 'lift', 'CARD', '01223585236', 'reminder', 'When/where', 'split', 'boye', 'Select', 'temales', 'bhaji', 'teaching', 'connection', 'readiness', 'Ciao', 'callon', 'Audrey', 'can\x89Û÷t', 'amused', 'blanked', 'New', 'IQ', 'Wn', 'WIV', 'brother', 'secondary', 'Sunshine', 'test', 'triumphed', 'BOX385', 'courtroom', 'Easy', 'im', '1YF', 'Always', 'spirit', '150p/min', 'looovvve', 'area', '140ppm', 'suggestion', 'earn', 'D=', 'Imprtant', 'confirm', 'affidavit', 'Loans', 'die', 'PC', '88066', 'Sh', 'cst', 'vilikkam', 'absolutly', '150p/day', 'pleased', 'Fat', 'payasam', 'inpersonation', '2MORRO', 'toss', '08714712388', 'poop', 'refused', 'needa', 'Meet+Greet', 'SUNDAY', 'No1', 'Atlast', 'å£600', 'Fills', "'its", 'Tease', 'linerental', 'Mayb', 'Min', 'lamp', 'Dvd', 'Subscriber', 'Flight', 'mrng', 'Usually', 'boy', 'SAME', 'dis', 'Later', '68866', 'part', 'rental', 'WORK', 'Log', 'range', 'becoz', 'cared', 'Takin', 'Strip', 'tui', '-PLS', ...
# Modified lemmatized vector: {'brum', 'www.txt-2-shop.com', 'yoville', 'fowler', 'swann', 'mt', 'gossip', 'HAV', '-P', 'get4an18th', 'Don\x89Û÷t', 'person.Meet', 'grumble', 'abt', 'dealing', 'NO-165', 'individual', 'last', 'w1t1jy', 'Twittering', 'DE', 'LtdHelpDesk', 'mumHas', '25', 'eå£nd', 'njan', 'channel', 'operator', 'Subs', 'prolly', 'them', 'survey', '24th', 'northampton', 'KNOWS', 'More', 'green', 'mode', 'offline', 'Sagamu', 'Hello\\', 'message', 'canlove', 'renewing', 'drvgsTo', 'spk', 'win150ppmx3age16', 'fifteen', 'sd', 'support', 'rumbling', 'slowly', 'Smith', 'SOON', 'videosounds+2', 'great.bye', 'blimey', 'Oops', '87070', 'Lul', 'T-Mobile', 'Each', 'Iyo', 'personal', '151', 'derek', 'priest', 'person', 'chennai', 'kz', 'Guess', '82242', '2day.love', 'odi', 'wildlife', 'PlanetTalkInstant.com', 'INVITED', 'smeone', 'hunny', '08714712379', 'shldxxxx', 'ego', 'flow', 'iZ', 'jiu', 'W14RG', 'possessiveness', 'math', 'yeovil', 'CAREFUL', 'Shivratri', 'MISSED', 'physic', 'gym', 'w8in', 'Yun', 'dose', 'TOTALLY', 'LUV', 'hamper', 'strt', 'Videos', 'Saeed', 'Sometimes', 'failing', 'Jackpot', '09061702893', 'pickle', 'Chat80155', 'itcould', 'E.G.23F', '4.49/month', 'FREEPHONE', 'Pray', 'bowl', 'Read', 'snowman', 'Urgh', 'Horrible', 'urgently', '118p/msg', 'Hype', 'chance', 'telly', 'tookplace', 'Become', 'become', 'badly', 'PIN', 'Queries', 'Wins', 'dined', 'gave', 'GOODFRIEND', 'missed', 'Ptbo', 'REALLY', 'Yep', 'URL', 'Australia', 'a', 'Yalru', '09064017295', 'muchand', 'base', 'motherfucker', 'lookin', 'provided', 'ansr', 'nail', 'java', 'fgkslpo', 'fishhead', 'orc', 'matter', 'shortly', '4thNOV.BEHIND', 'pg', 'unsubscribe', 'yourinclusive', 'volcano', 'NUMBER-SO', 'flea', 'GOODTIME', 'prescripiton', '2go.did', 'YES-165', '4-7/12', 'bos', '4.50', 'scratch', 'kiosk', 'Join', '09058094597', '7ish', 'unfortuntly', '7', 'WORDS', 'selflessness', '3qxj9', 'LOOKIN', 'account', 'Rajitha', 'MARSMS', 'sparkling', 'Common', 'temper', 'wkg', 'Everytime', 'Dorothy', 'Emily', 'clue', 'cheek', 'qatar', 'atlast', 'profit', 'frens', 'salmon', 'first', 'mornin', 'Nokia', 'gd', 'tear', 'lecture', 'Minimum', 'LIKELY', 'james', 'Abiola', 'pocked', 'Tomarrow', 'performed', 'oga', 'magicalsongs.blogspot.com', 'refreshed', 'alert', 'Nite', '021', 'MARCH', 'FML', 'semester', 'that\x89Û÷s', 'dippeditinaDEW', 'flower', 'billion', '3AJ', 'Yesterday', 'AVA', 'ad', 'progress', 'purse', "'anything", 'me.Remove', 'Hugs', 'tonite.things', '24/7MP', 'EURO', 'Girl', 'renting', 'Then', 'wishin', 'å£350', 'section', 'INK', 'he', 'Gal', 'husband', 'b', 'sony', 'blame', 'Happy', 'Drop', 'bootydelious', 'ovarian', 'arises', '2.IM', 'urination', 'sacked', 'ax', 'hai', 'mutai', 'ppm', 'won', 'technical', 'gnun', '8+6+3=', 'earliest', 'QUITEAMUZING', 'paining', 'KEEP', 'macho', 'remember', 'wildest', 'bad-', 'GOWER', 'Nt', 'bw', '\\HI', 'gist', 'prior', 'creep', 'Rally', 'yi', 'ended', 'Melle', 'tie-pos', 'lodge', 'birth', 'seeker', 'Alaikkum.Pride', 'recovery', 'subsequent', 'Jamster', 'London', 'virgil', 'ou', 'Lands', 'contact', 'Next', 'lift', 'CARD', '01223585236', 'reminder', 'When/where', 'split', 'boye', 'Select', 'temales', 'bhaji', 'teaching', 'connection', 'readiness', 'Ciao', 'callon', 'Audrey', 'can\x89Û÷t', 'amused', 'blanked', 'New', 'IQ', 'Wn', 'WIV', 'brother', 'secondary', 'Sunshine', 'test', 'triumphed', 'BOX385', 'courtroom', 'Easy', 'im', '1YF', 'Always', 'spirit', '150p/min', 'looovvve', 'area', '140ppm', 'suggestion', 'earn', 'D=', 'Imprtant', 'confirm', 'affidavit', 'Loans', 'die', 'PC', '88066', 'Sh', 'cst', 'vilikkam', 'absolutly', '150p/day', 'pleased', 'Fat', 'payasam', 'inpersonation', '2MORRO', 'toss', '08714712388', 'poop', 'refused', 'needa', 'Meet+Greet', 'SUNDAY', 'No1', 'Atlast', 'å£600', 'Fills', "'its", 'Tease', 'linerental', 'Mayb', 'Min', 'lamp', 'Dvd', 'Subscriber', 'Flight', 'mrng', 'Usually', 'boy', 'SAME', 'dis', 'Later', '68866', 'part', 'rental', 'WORK', 'Log', 'range', 'becoz', 'cared', 'Takin', 'Strip', 'tui', '-PLS', ...
# Proof: The lemmatized vectors are identical, so removing this message does not affect lemmatized tokens.
